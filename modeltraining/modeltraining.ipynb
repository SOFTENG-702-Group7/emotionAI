# %%
# Load the necessary libraries
import pandas as pd
import os
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.metrics import  classification_report
import seaborn as sns
from PIL import Image
import timm

# %%
# Load the dataset from the CSV file
df = pd.read_csv('labels.csv')

# Drop the unnecessary column 'Unnamed: 0' from the DataFrame
df = df.drop('Unnamed: 0', axis=1)

# Convert the image paths to string type
df['pth'] = df['pth'].astype(str)

# Define the label mapping for emotions to numerical values
classes = {
    "anger": 0,
    "disgust": 1,
    "fear": 2,
    "happy": 3,
    "sad": 4,
    "surprise": 5,
    "netural": 6
}
num_classes = len(classes) # Number of classes

# Drop rows with labels that are not in the defined classes
df = df[df['label'].isin(classes.keys())]

# Apply the label mapping to the 'label' column
df['label'] = df['label'].map(classes)

# Split the dataset into training and validation sets with stratification
train_df, validation_df = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=42)

# %%
# Define the transformations to apply to the images
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images to 224x224
    transforms.ToTensor(),          # Convert images to PyTorch tensors
    transforms.Normalize((0.5,), (0.5,))  # Normalize the images
])


# Create a dataset using the DataFrame without a custom class
class CustomImageDataset(Dataset):
    def __init__(self, df, root_dir='./', transform=None):
        self.df = df # DataFrame containing the image paths and labels
        self.root_dir = root_dir # Root directory containing the images
        self.transform = transform # Transformations to apply to the images
        self.image_paths = self.df['pth'].values # Image paths
        self.labels = self.df['label'].values # Corresponding labels

    def __len__(self):
        """Return the total number of samples in the dataset."""
        return len(self.image_paths)

    def __getitem__(self, idx):
        """Retrieve a sample from the dataset."""
        # Get the image path
        image_path = os.path.join(self.root_dir, self.image_paths[idx])
        
        # Open and convert the image to RGB
        image = Image.open(image_path).convert('RGB')
        
        # Apply the transform if it exists
        if self.transform:
            image = self.transform(image)
        
        # Get the class index from the label
        class_idx = self.labels[idx]
        
        # Create a one-hot encoded label tensor
        label = torch.zeros(num_classes)
        label[class_idx] = 1
        
        return image, label # Return the image and one-hot encoded label


# Create datasets for training and validation
train_dataset = CustomImageDataset(train_df, transform=transform)
validation_dataset = CustomImageDataset(validation_df, transform=transform)

# Get number of images in each dataset
num_train_images = len(train_dataset)
num_validation_images = len(validation_dataset)

print(f'Number of training images: {num_train_images}')
print(f'Number of validation images: {num_validation_images}')

# Create DataLoaders for training and validation
batch_size = 10
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Number of training images: 17656
# Number of validation images: 4414

# %%
# Define a Trainer class to handle the training and validation process
class Trainer:
    def __init__(self, save_path, num_epochs):
        self.num_epochs = num_epochs # Number of training epochs
        self.save_path = save_path # Path to save model checkpoints

        # Initialize the model
        self.model = timm.create_model('convnext_pico.d1_in1k', pretrained=True)
        self.model.head.fc = nn.Linear(512, 7) # Change the number of output classes to 7

        # Define loss function (cross-entropy loss)
        self.criterion = nn.CrossEntropyLoss()

        # Define optimizer (Adam optimizer)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.00001)

        # Set device (GPU if available, else CPU)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device) # Move the model to the device
        print(f"Using device: {self.device} \n")

    def validate(self, epoch):
        """Perform validation on the validation set."""
        self.model.eval() # Set the model to evaluation mode
        print("Validating...")

        running_loss = 0.0
        total_loss = 0.0
        total = 0
        correct = 0
        with torch.no_grad(): # Disable gradient computation
            for i, data in enumerate(validation_loader):
                images, labels = (data[0].to(self.device), data[1].to(self.device))
                outputs = self.model(images)
                loss = self.criterion(outputs, labels)

                # Calculate loss
                total_loss += loss.item()
                running_loss += loss.item()

                # Calculate accuracy
                predicted = torch.argmax(outputs.data, 1)
                predicted_labels = torch.argmax(labels.data, 1)
                total += labels.size(0)
                correct += (predicted == predicted_labels).sum().item()

                # Calculate average validation loss for the last 100 batches
                if (i + 1) % 100 == 0:
                    print('Validation Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        epoch, (i + 1) * len(images), len(validation_loader.dataset),
                        100. * (i + 1) / len(validation_loader), running_loss / 100))
                    running_loss = 0.

        avg_loss = total_loss / len(validation_loader) # Average validation loss
        accuracy = 100 * correct / total # Validation accuracy

        # Save the model checkpoint
        os.makedirs(self.save_path, exist_ok=True)
        torch.save(self.model, self.save_path + os.sep + 'cnn-{}.pt'.format(epoch))

        return avg_loss, accuracy # Return average validation loss and accuracy
    
    def train_one_epoch(self, epoch):
        """Train the model for one epoch."""
        self.model.train() # Set the model to training mode
        print("Training...")

        running_loss = 0.0
        total_loss = 0.0
        total = 0
        correct = 0
        for i, data in enumerate(train_loader):
            images, labels = (data[0].to(self.device), data[1].to(self.device))
            self.optimizer.zero_grad() # Clear the gradients
            outputs = self.model(images)
            loss = self.criterion(outputs, labels)
            
            loss.backward() # Backpropagate the loss
            self.optimizer.step() # Update the model parameters
            
            # Calculate loss
            total_loss += loss.item()
            running_loss += loss.item()

            # Calculate accuracy
            predicted = torch.argmax(outputs.data, 1)
            predicted_labels = torch.argmax(labels.data, 1)
            total += labels.size(0)
            correct += (predicted == predicted_labels).sum().item()

            # Calculate average training loss for the last 100 batches
            if (i + 1) % 100 == 0:
                print('Training Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch, (i + 1) * len(images), len(train_loader.dataset),
                    100. * (i + 1) / len(train_loader), running_loss / 100))
                running_loss = 0.

        avg_loss = total_loss / len(train_loader) # Average training loss
        accuracy = 100 * correct / total # Training accuracy

        return avg_loss, accuracy # Return average training loss and accuracy
    
    def train(self):
        self.train_losses = [] # Store training losses
        self.validation_losses = [] # Store validation losses
        self.train_accuracies = [] # Store training accuracies
        self.validation_accuracies = [] # Store validation accuracies

        for epoch in range(self.num_epochs):
            print('EPOCH {}:'.format(epoch+1))

            # Train and validate for one epoch
            train_loss, train_accuracy = self.train_one_epoch(epoch+1)
            validation_loss, validation_accuracy = self.validate(epoch+1)
            print('Training Loss: {:.8f} \tValidation Loss {:.8f} \tTraining Accuracy {:.3f}% \tValidation Accuracy {:.3f}% \n'
                                                        .format(train_loss,validation_loss, train_accuracy, validation_accuracy))
            
            # Store training and validation metrics
            self.train_losses.append(train_loss.cpu().item() if torch.is_tensor(train_loss) else train_loss)
            self.train_accuracies.append(train_accuracy.cpu().item() if torch.is_tensor(train_accuracy) else train_accuracy)
            self.validation_losses.append(validation_loss.cpu().item() if torch.is_tensor(validation_loss) else validation_loss)
            self.validation_accuracies.append(validation_accuracy.cpu().item() if torch.is_tensor(validation_accuracy) else validation_accuracy)
            

# Set the path for saving model checkpoints and number of epochs
save_path = 'model_checkpoints'
num_epochs = 40
trainer = Trainer(save_path, num_epochs) # Instantiate the Trainer class
trainer.train() # Start the training process
# Out:
# Using device: cpu
#
# EPOCH 1:
# Training...
# Training Epoch: 1 [1000/17656 (6%)]	Loss: 1.788902
# Training Epoch: 1 [2000/17656 (11%)]	Loss: 1.562347
# Training Epoch: 1 [3000/17656 (17%)]	Loss: 1.428034
# Training Epoch: 1 [4000/17656 (23%)]	Loss: 1.286786
# Training Epoch: 1 [5000/17656 (28%)]	Loss: 1.230498
# Training Epoch: 1 [6000/17656 (34%)]	Loss: 1.178919
# Training Epoch: 1 [7000/17656 (40%)]	Loss: 1.144751
# Training Epoch: 1 [8000/17656 (45%)]	Loss: 1.111628
# Training Epoch: 1 [9000/17656 (51%)]	Loss: 1.068705
# Training Epoch: 1 [10000/17656 (57%)]	Loss: 1.038430
# Training Epoch: 1 [11000/17656 (62%)]	Loss: 1.013895
# Training Epoch: 1 [12000/17656 (68%)]	Loss: 1.004499
# Training Epoch: 1 [13000/17656 (74%)]	Loss: 0.937379
# Training Epoch: 1 [14000/17656 (79%)]	Loss: 0.969765
# Training Epoch: 1 [15000/17656 (85%)]	Loss: 0.924308
# Training Epoch: 1 [16000/17656 (91%)]	Loss: 0.904880
# Training Epoch: 1 [17000/17656 (96%)]	Loss: 0.875361
# Validating...
# Validation Epoch: 1 [1000/4414 (23%)]	Loss: 0.818413
# Validation Epoch: 1 [2000/4414 (45%)]	Loss: 0.831385
# Validation Epoch: 1 [3000/4414 (68%)]	Loss: 0.876731
# Validation Epoch: 1 [4000/4414 (90%)]	Loss: 0.824498
# Training Loss: 1.13667647 	Validation Loss 0.83600839 	Training Accuracy 54.554% 	Validation Accuracy 68.691%
#
# EPOCH 2:
# Training...
# Training Epoch: 2 [1000/17656 (6%)]	Loss: 0.796843
# Training Epoch: 2 [2000/17656 (11%)]	Loss: 0.764234
# Training Epoch: 2 [3000/17656 (17%)]	Loss: 0.762252
# Training Epoch: 2 [4000/17656 (23%)]	Loss: 0.761771
# Training Epoch: 2 [5000/17656 (28%)]	Loss: 0.759715
# Training Epoch: 2 [6000/17656 (34%)]	Loss: 0.719712
# Training Epoch: 2 [7000/17656 (40%)]	Loss: 0.717955
# Training Epoch: 2 [8000/17656 (45%)]	Loss: 0.657410
# Training Epoch: 2 [9000/17656 (51%)]	Loss: 0.707393
# Training Epoch: 2 [10000/17656 (57%)]	Loss: 0.680723
# Training Epoch: 2 [11000/17656 (62%)]	Loss: 0.631309
# Training Epoch: 2 [12000/17656 (68%)]	Loss: 0.704083
# Training Epoch: 2 [13000/17656 (74%)]	Loss: 0.684994
# Training Epoch: 2 [14000/17656 (79%)]	Loss: 0.725991
# Training Epoch: 2 [15000/17656 (85%)]	Loss: 0.655767
# Training Epoch: 2 [16000/17656 (91%)]	Loss: 0.718917
# Training Epoch: 2 [17000/17656 (96%)]	Loss: 0.627193
# Validating...
# Validation Epoch: 2 [1000/4414 (23%)]	Loss: 0.700037
# Validation Epoch: 2 [2000/4414 (45%)]	Loss: 0.730393
# Validation Epoch: 2 [3000/4414 (68%)]	Loss: 0.766882
# Validation Epoch: 2 [4000/4414 (90%)]	Loss: 0.684202
# Training Loss: 0.70863657 	Validation Loss 0.72178058 	Training Accuracy 72.972% 	Validation Accuracy 72.587%
#
# EPOCH 3:
# Training...
# Training Epoch: 3 [1000/17656 (6%)]	Loss: 0.543740
# Training Epoch: 3 [2000/17656 (11%)]	Loss: 0.544523
# Training Epoch: 3 [3000/17656 (17%)]	Loss: 0.510545
# Training Epoch: 3 [4000/17656 (23%)]	Loss: 0.471719
# Training Epoch: 3 [5000/17656 (28%)]	Loss: 0.514465
# Training Epoch: 3 [6000/17656 (34%)]	Loss: 0.527006
# Training Epoch: 3 [7000/17656 (40%)]	Loss: 0.549650
# Training Epoch: 3 [8000/17656 (45%)]	Loss: 0.483532
# Training Epoch: 3 [9000/17656 (51%)]	Loss: 0.548775
# Training Epoch: 3 [10000/17656 (57%)]	Loss: 0.496175
# Training Epoch: 3 [11000/17656 (62%)]	Loss: 0.498263
# Training Epoch: 3 [12000/17656 (68%)]	Loss: 0.466210
# Training Epoch: 3 [13000/17656 (74%)]	Loss: 0.538520
# Training Epoch: 3 [14000/17656 (79%)]	Loss: 0.475751
# Training Epoch: 3 [15000/17656 (85%)]	Loss: 0.530445
# Training Epoch: 3 [16000/17656 (91%)]	Loss: 0.502232
# Training Epoch: 3 [17000/17656 (96%)]	Loss: 0.516667
# Validating...
# Validation Epoch: 3 [1000/4414 (23%)]	Loss: 0.640225
# Validation Epoch: 3 [2000/4414 (45%)]	Loss: 0.650288
# Validation Epoch: 3 [3000/4414 (68%)]	Loss: 0.697555
# Validation Epoch: 3 [4000/4414 (90%)]	Loss: 0.653560
# Training Loss: 0.51069779 	Validation Loss 0.65561156 	Training Accuracy 80.720% 	Validation Accuracy 74.966%
#
# EPOCH 4:
# Training...
# Training Epoch: 4 [1000/17656 (6%)]	Loss: 0.371961
# Training Epoch: 4 [2000/17656 (11%)]	Loss: 0.375927
# Training Epoch: 4 [3000/17656 (17%)]	Loss: 0.391730
# Training Epoch: 4 [4000/17656 (23%)]	Loss: 0.381763
# Training Epoch: 4 [5000/17656 (28%)]	Loss: 0.376786
# Training Epoch: 4 [6000/17656 (34%)]	Loss: 0.360611
# Training Epoch: 4 [7000/17656 (40%)]	Loss: 0.342167
# Training Epoch: 4 [8000/17656 (45%)]	Loss: 0.375224
# Training Epoch: 4 [9000/17656 (51%)]	Loss: 0.321537
# Training Epoch: 4 [10000/17656 (57%)]	Loss: 0.343293
# Training Epoch: 4 [11000/17656 (62%)]	Loss: 0.354030
# Training Epoch: 4 [12000/17656 (68%)]	Loss: 0.356521
# Training Epoch: 4 [13000/17656 (74%)]	Loss: 0.391620
# Training Epoch: 4 [14000/17656 (79%)]	Loss: 0.376923
# Training Epoch: 4 [15000/17656 (85%)]	Loss: 0.337884
# Training Epoch: 4 [16000/17656 (91%)]	Loss: 0.367939
# Training Epoch: 4 [17000/17656 (96%)]	Loss: 0.354466
# Validating...
# Validation Epoch: 4 [1000/4414 (23%)]	Loss: 0.614522
# Validation Epoch: 4 [2000/4414 (45%)]	Loss: 0.649215
# Validation Epoch: 4 [3000/4414 (68%)]	Loss: 0.679327
# Validation Epoch: 4 [4000/4414 (90%)]	Loss: 0.640963
# Training Loss: 0.36212888 	Validation Loss 0.63950442 	Training Accuracy 87.064% 	Validation Accuracy 76.416%
#
# EPOCH 5:
# Training...
# Training Epoch: 5 [1000/17656 (6%)]	Loss: 0.230339
# Training Epoch: 5 [2000/17656 (11%)]	Loss: 0.229736
# Training Epoch: 5 [3000/17656 (17%)]	Loss: 0.199297
# Training Epoch: 5 [4000/17656 (23%)]	Loss: 0.218150
# Training Epoch: 5 [5000/17656 (28%)]	Loss: 0.221939
# Training Epoch: 5 [6000/17656 (34%)]	Loss: 0.242786
# Training Epoch: 5 [7000/17656 (40%)]	Loss: 0.234157
# Training Epoch: 5 [8000/17656 (45%)]	Loss: 0.244931
# Training Epoch: 5 [9000/17656 (51%)]	Loss: 0.238682
# Training Epoch: 5 [10000/17656 (57%)]	Loss: 0.262146
# Training Epoch: 5 [11000/17656 (62%)]	Loss: 0.227733
# Training Epoch: 5 [12000/17656 (68%)]	Loss: 0.223172
# Training Epoch: 5 [13000/17656 (74%)]	Loss: 0.255720
# Training Epoch: 5 [14000/17656 (79%)]	Loss: 0.242777
# Training Epoch: 5 [15000/17656 (85%)]	Loss: 0.217688
# Training Epoch: 5 [16000/17656 (91%)]	Loss: 0.299818
# Training Epoch: 5 [17000/17656 (96%)]	Loss: 0.239932
# Validating...
# Validation Epoch: 5 [1000/4414 (23%)]	Loss: 0.642498
# Validation Epoch: 5 [2000/4414 (45%)]	Loss: 0.694505
# Validation Epoch: 5 [3000/4414 (68%)]	Loss: 0.732407
# Validation Epoch: 5 [4000/4414 (90%)]	Loss: 0.628291
# Training Loss: 0.23703357 	Validation Loss 0.66768768 	Training Accuracy 91.946% 	Validation Accuracy 76.031%
#
# EPOCH 6:
# Training...
# Training Epoch: 6 [1000/17656 (6%)]	Loss: 0.121529
# Training Epoch: 6 [2000/17656 (11%)]	Loss: 0.121523
# Training Epoch: 6 [3000/17656 (17%)]	Loss: 0.117523
# Training Epoch: 6 [4000/17656 (23%)]	Loss: 0.122949
# Training Epoch: 6 [5000/17656 (28%)]	Loss: 0.116872
# Training Epoch: 6 [6000/17656 (34%)]	Loss: 0.130419
# Training Epoch: 6 [7000/17656 (40%)]	Loss: 0.140042
# Training Epoch: 6 [8000/17656 (45%)]	Loss: 0.117974
# Training Epoch: 6 [9000/17656 (51%)]	Loss: 0.132072
# Training Epoch: 6 [10000/17656 (57%)]	Loss: 0.140767
# Training Epoch: 6 [11000/17656 (62%)]	Loss: 0.132711
# Training Epoch: 6 [12000/17656 (68%)]	Loss: 0.151740
# Training Epoch: 6 [13000/17656 (74%)]	Loss: 0.126289
# Training Epoch: 6 [14000/17656 (79%)]	Loss: 0.138470
# Training Epoch: 6 [15000/17656 (85%)]	Loss: 0.168992
# Training Epoch: 6 [16000/17656 (91%)]	Loss: 0.157693
# Training Epoch: 6 [17000/17656 (96%)]	Loss: 0.134347
# Validating...
# Validation Epoch: 6 [1000/4414 (23%)]	Loss: 0.771929
# Validation Epoch: 6 [2000/4414 (45%)]	Loss: 0.786704
# Validation Epoch: 6 [3000/4414 (68%)]	Loss: 0.817610
# Validation Epoch: 6 [4000/4414 (90%)]	Loss: 0.789234
# Training Loss: 0.13417210 	Validation Loss 0.78026674 	Training Accuracy 96.098% 	Validation Accuracy 75.918%
#
# EPOCH 7:
# Training...
# Training Epoch: 7 [1000/17656 (6%)]	Loss: 0.072322
# Training Epoch: 7 [2000/17656 (11%)]	Loss: 0.059761
# Training Epoch: 7 [3000/17656 (17%)]	Loss: 0.055810
# Training Epoch: 7 [4000/17656 (23%)]	Loss: 0.060271
# Training Epoch: 7 [5000/17656 (28%)]	Loss: 0.052359
# Training Epoch: 7 [6000/17656 (34%)]	Loss: 0.060934
# Training Epoch: 7 [7000/17656 (40%)]	Loss: 0.060725
# Training Epoch: 7 [8000/17656 (45%)]	Loss: 0.080130
# Training Epoch: 7 [9000/17656 (51%)]	Loss: 0.065004
# Training Epoch: 7 [10000/17656 (57%)]	Loss: 0.051583
# Training Epoch: 7 [11000/17656 (62%)]	Loss: 0.047788
# Training Epoch: 7 [12000/17656 (68%)]	Loss: 0.050362
# Training Epoch: 7 [13000/17656 (74%)]	Loss: 0.070968
# Training Epoch: 7 [14000/17656 (79%)]	Loss: 0.060349
# Training Epoch: 7 [15000/17656 (85%)]	Loss: 0.072377
# Training Epoch: 7 [16000/17656 (91%)]	Loss: 0.086662
# Training Epoch: 7 [17000/17656 (96%)]	Loss: 0.080179
# Validating...
# Validation Epoch: 7 [1000/4414 (23%)]	Loss: 0.822868
# Validation Epoch: 7 [2000/4414 (45%)]	Loss: 0.881044
# Validation Epoch: 7 [3000/4414 (68%)]	Loss: 0.907740
# Validation Epoch: 7 [4000/4414 (90%)]	Loss: 0.802540
# Training Loss: 0.06509338 	Validation Loss 0.84445029 	Training Accuracy 98.584% 	Validation Accuracy 75.283%
#
# EPOCH 8:
# Training...
# Training Epoch: 8 [1000/17656 (6%)]	Loss: 0.028666
# Training Epoch: 8 [2000/17656 (11%)]	Loss: 0.027234
# Training Epoch: 8 [3000/17656 (17%)]	Loss: 0.029776
# Training Epoch: 8 [4000/17656 (23%)]	Loss: 0.026289
# Training Epoch: 8 [5000/17656 (28%)]	Loss: 0.023803
# Training Epoch: 8 [6000/17656 (34%)]	Loss: 0.027837
# Training Epoch: 8 [7000/17656 (40%)]	Loss: 0.049927
# Training Epoch: 8 [8000/17656 (45%)]	Loss: 0.039250
# Training Epoch: 8 [9000/17656 (51%)]	Loss: 0.038547
# Training Epoch: 8 [10000/17656 (57%)]	Loss: 0.042106
# Training Epoch: 8 [11000/17656 (62%)]	Loss: 0.048425
# Training Epoch: 8 [12000/17656 (68%)]	Loss: 0.058070
# Training Epoch: 8 [13000/17656 (74%)]	Loss: 0.056883
# Training Epoch: 8 [14000/17656 (79%)]	Loss: 0.043026
# Training Epoch: 8 [15000/17656 (85%)]	Loss: 0.048888
# Training Epoch: 8 [16000/17656 (91%)]	Loss: 0.067896
# Training Epoch: 8 [17000/17656 (96%)]	Loss: 0.044162
# Validating...
# Validation Epoch: 8 [1000/4414 (23%)]	Loss: 0.875210
# Validation Epoch: 8 [2000/4414 (45%)]	Loss: 0.931711
# Validation Epoch: 8 [3000/4414 (68%)]	Loss: 0.978847
# Validation Epoch: 8 [4000/4414 (90%)]	Loss: 0.881798
# Training Loss: 0.04085688 	Validation Loss 0.90893891 	Training Accuracy 99.173% 	Validation Accuracy 76.733%
#
# EPOCH 9:
# Training...
# Training Epoch: 9 [1000/17656 (6%)]	Loss: 0.014648
# Training Epoch: 9 [2000/17656 (11%)]	Loss: 0.014836
# Training Epoch: 9 [3000/17656 (17%)]	Loss: 0.014429
# Training Epoch: 9 [4000/17656 (23%)]	Loss: 0.015193
# Training Epoch: 9 [5000/17656 (28%)]	Loss: 0.022193
# Training Epoch: 9 [6000/17656 (34%)]	Loss: 0.037196
# Training Epoch: 9 [7000/17656 (40%)]	Loss: 0.026833
# Training Epoch: 9 [8000/17656 (45%)]	Loss: 0.022308
# Training Epoch: 9 [9000/17656 (51%)]	Loss: 0.018094
# Training Epoch: 9 [10000/17656 (57%)]	Loss: 0.018297
# Training Epoch: 9 [11000/17656 (62%)]	Loss: 0.033185
# Training Epoch: 9 [12000/17656 (68%)]	Loss: 0.050463
# Training Epoch: 9 [13000/17656 (74%)]	Loss: 0.057728
# Training Epoch: 9 [14000/17656 (79%)]	Loss: 0.029248
# Training Epoch: 9 [15000/17656 (85%)]	Loss: 0.041753
# Training Epoch: 9 [16000/17656 (91%)]	Loss: 0.029847
# Training Epoch: 9 [17000/17656 (96%)]	Loss: 0.030464
# Validating...
# Validation Epoch: 9 [1000/4414 (23%)]	Loss: 0.913721
# Validation Epoch: 9 [2000/4414 (45%)]	Loss: 0.978327
# Validation Epoch: 9 [3000/4414 (68%)]	Loss: 0.984593
# Validation Epoch: 9 [4000/4414 (90%)]	Loss: 0.879118
# Training Loss: 0.02809703 	Validation Loss 0.92652718 	Training Accuracy 99.360% 	Validation Accuracy 76.575%
#
# EPOCH 10:
# Training...
# Training Epoch: 10 [1000/17656 (6%)]	Loss: 0.011725
# Training Epoch: 10 [2000/17656 (11%)]	Loss: 0.020559
# Training Epoch: 10 [3000/17656 (17%)]	Loss: 0.010963
# Training Epoch: 10 [4000/17656 (23%)]	Loss: 0.009606
# Training Epoch: 10 [5000/17656 (28%)]	Loss: 0.007529
# Training Epoch: 10 [6000/17656 (34%)]	Loss: 0.004968
# Training Epoch: 10 [7000/17656 (40%)]	Loss: 0.007524
# Training Epoch: 10 [8000/17656 (45%)]	Loss: 0.009552
# Training Epoch: 10 [9000/17656 (51%)]	Loss: 0.004949
# Training Epoch: 10 [10000/17656 (57%)]	Loss: 0.006525
# Training Epoch: 10 [11000/17656 (62%)]	Loss: 0.005248
# Training Epoch: 10 [12000/17656 (68%)]	Loss: 0.010209
# Training Epoch: 10 [13000/17656 (74%)]	Loss: 0.049096
# Training Epoch: 10 [14000/17656 (79%)]	Loss: 0.154371
# Training Epoch: 10 [15000/17656 (85%)]	Loss: 0.068502
# Training Epoch: 10 [16000/17656 (91%)]	Loss: 0.081707
# Training Epoch: 10 [17000/17656 (96%)]	Loss: 0.042544
# Validating...
# Validation Epoch: 10 [1000/4414 (23%)]	Loss: 0.982139
# Validation Epoch: 10 [2000/4414 (45%)]	Loss: 0.979925
# Validation Epoch: 10 [3000/4414 (68%)]	Loss: 1.030366
# Validation Epoch: 10 [4000/4414 (90%)]	Loss: 0.905535
# Training Loss: 0.02962980 	Validation Loss 0.95892500 	Training Accuracy 99.179% 	Validation Accuracy 76.597%
#
# EPOCH 11:
# Training...
# Training Epoch: 11 [1000/17656 (6%)]	Loss: 0.007637
# Training Epoch: 11 [2000/17656 (11%)]	Loss: 0.011197
# Training Epoch: 11 [3000/17656 (17%)]	Loss: 0.006215
# Training Epoch: 11 [4000/17656 (23%)]	Loss: 0.007143
# Training Epoch: 11 [5000/17656 (28%)]	Loss: 0.006740
# Training Epoch: 11 [6000/17656 (34%)]	Loss: 0.006037
# Training Epoch: 11 [7000/17656 (40%)]	Loss: 0.007405
# Training Epoch: 11 [8000/17656 (45%)]	Loss: 0.004020
# Training Epoch: 11 [9000/17656 (51%)]	Loss: 0.004496
# Training Epoch: 11 [10000/17656 (57%)]	Loss: 0.004301
# Training Epoch: 11 [11000/17656 (62%)]	Loss: 0.004360
# Training Epoch: 11 [12000/17656 (68%)]	Loss: 0.004206
# Training Epoch: 11 [13000/17656 (74%)]	Loss: 0.004556
# Training Epoch: 11 [14000/17656 (79%)]	Loss: 0.111842
# Training Epoch: 11 [15000/17656 (85%)]	Loss: 0.070459
# Training Epoch: 11 [16000/17656 (91%)]	Loss: 0.068831
# Training Epoch: 11 [17000/17656 (96%)]	Loss: 0.027499
# Validating...
# Validation Epoch: 11 [1000/4414 (23%)]	Loss: 1.088727
# Validation Epoch: 11 [2000/4414 (45%)]	Loss: 1.078241
# Validation Epoch: 11 [3000/4414 (68%)]	Loss: 1.174698
# Validation Epoch: 11 [4000/4414 (90%)]	Loss: 1.066174
# Training Loss: 0.02121717 	Validation Loss 1.08638249 	Training Accuracy 99.411% 	Validation Accuracy 75.736%
#
# EPOCH 12:
# Training...
# Training Epoch: 12 [1000/17656 (6%)]	Loss: 0.019495
# Training Epoch: 12 [2000/17656 (11%)]	Loss: 0.016730
# Training Epoch: 12 [3000/17656 (17%)]	Loss: 0.024866
# Training Epoch: 12 [4000/17656 (23%)]	Loss: 0.009687
# Training Epoch: 12 [5000/17656 (28%)]	Loss: 0.006892
# Training Epoch: 12 [6000/17656 (34%)]	Loss: 0.006922
# Training Epoch: 12 [7000/17656 (40%)]	Loss: 0.009056
# Training Epoch: 12 [8000/17656 (45%)]	Loss: 0.007065
# Training Epoch: 12 [9000/17656 (51%)]	Loss: 0.005633
# Training Epoch: 12 [10000/17656 (57%)]	Loss: 0.004424
# Training Epoch: 12 [11000/17656 (62%)]	Loss: 0.004212
# Training Epoch: 12 [12000/17656 (68%)]	Loss: 0.002758
# Training Epoch: 12 [13000/17656 (74%)]	Loss: 0.043076
# Training Epoch: 12 [14000/17656 (79%)]	Loss: 0.087346
# Training Epoch: 12 [15000/17656 (85%)]	Loss: 0.045715
# Training Epoch: 12 [16000/17656 (91%)]	Loss: 0.015952
# Training Epoch: 12 [17000/17656 (96%)]	Loss: 0.008450
# Validating...
# Validation Epoch: 12 [1000/4414 (23%)]	Loss: 1.017433
# Validation Epoch: 12 [2000/4414 (45%)]	Loss: 1.020030
# Validation Epoch: 12 [3000/4414 (68%)]	Loss: 1.172612
# Validation Epoch: 12 [4000/4414 (90%)]	Loss: 1.047186
# Training Loss: 0.01848617 	Validation Loss 1.04855888 	Training Accuracy 99.530% 	Validation Accuracy 76.960%
#
# EPOCH 13:
# Training...
# Training Epoch: 13 [1000/17656 (6%)]	Loss: 0.008473
# Training Epoch: 13 [2000/17656 (11%)]	Loss: 0.012732
# Training Epoch: 13 [3000/17656 (17%)]	Loss: 0.004267
# Training Epoch: 13 [4000/17656 (23%)]	Loss: 0.006881
# Training Epoch: 13 [5000/17656 (28%)]	Loss: 0.011840
# Training Epoch: 13 [6000/17656 (34%)]	Loss: 0.011215
# Training Epoch: 13 [7000/17656 (40%)]	Loss: 0.011034
# Training Epoch: 13 [8000/17656 (45%)]	Loss: 0.035420
# Training Epoch: 13 [9000/17656 (51%)]	Loss: 0.031608
# Training Epoch: 13 [10000/17656 (57%)]	Loss: 0.017118
# Training Epoch: 13 [11000/17656 (62%)]	Loss: 0.008927
# Training Epoch: 13 [12000/17656 (68%)]	Loss: 0.032888
# Training Epoch: 13 [13000/17656 (74%)]	Loss: 0.019314
# Training Epoch: 13 [14000/17656 (79%)]	Loss: 0.011887
# Training Epoch: 13 [15000/17656 (85%)]	Loss: 0.053449
# Training Epoch: 13 [16000/17656 (91%)]	Loss: 0.039686
# Training Epoch: 13 [17000/17656 (96%)]	Loss: 0.027914
# Validating...
# Validation Epoch: 13 [1000/4414 (23%)]	Loss: 1.053812
# Validation Epoch: 13 [2000/4414 (45%)]	Loss: 1.046302
# Validation Epoch: 13 [3000/4414 (68%)]	Loss: 1.138458
# Validation Epoch: 13 [4000/4414 (90%)]	Loss: 0.980260
# Training Loss: 0.02009294 	Validation Loss 1.04423687 	Training Accuracy 99.349% 	Validation Accuracy 76.597%
#
# EPOCH 14:
# Training...
# Training Epoch: 14 [1000/17656 (6%)]	Loss: 0.009401
# Training Epoch: 14 [2000/17656 (11%)]	Loss: 0.004413
# Training Epoch: 14 [3000/17656 (17%)]	Loss: 0.027727
# Training Epoch: 14 [4000/17656 (23%)]	Loss: 0.008126
# Training Epoch: 14 [5000/17656 (28%)]	Loss: 0.014109
# Training Epoch: 14 [6000/17656 (34%)]	Loss: 0.005127
# Training Epoch: 14 [7000/17656 (40%)]	Loss: 0.009353
# Training Epoch: 14 [8000/17656 (45%)]	Loss: 0.011794
# Training Epoch: 14 [9000/17656 (51%)]	Loss: 0.014532
# Training Epoch: 14 [10000/17656 (57%)]	Loss: 0.005185
# Training Epoch: 14 [11000/17656 (62%)]	Loss: 0.019370
# Training Epoch: 14 [12000/17656 (68%)]	Loss: 0.028499
# Training Epoch: 14 [13000/17656 (74%)]	Loss: 0.007793
# Training Epoch: 14 [14000/17656 (79%)]	Loss: 0.054066
# Training Epoch: 14 [15000/17656 (85%)]	Loss: 0.055018
# Training Epoch: 14 [16000/17656 (91%)]	Loss: 0.035735
# Training Epoch: 14 [17000/17656 (96%)]	Loss: 0.013720
# Validating...
# Validation Epoch: 14 [1000/4414 (23%)]	Loss: 1.116917
# Validation Epoch: 14 [2000/4414 (45%)]	Loss: 1.137646
# Validation Epoch: 14 [3000/4414 (68%)]	Loss: 1.238002
# Validation Epoch: 14 [4000/4414 (90%)]	Loss: 1.068651
# Training Loss: 0.01974525 	Validation Loss 1.12153759 	Training Accuracy 99.337% 	Validation Accuracy 75.940%
#
# EPOCH 15:
# Training...
# Training Epoch: 15 [1000/17656 (6%)]	Loss: 0.014166
# Training Epoch: 15 [2000/17656 (11%)]	Loss: 0.008270
# Training Epoch: 15 [3000/17656 (17%)]	Loss: 0.002575
# Training Epoch: 15 [4000/17656 (23%)]	Loss: 0.005161
# Training Epoch: 15 [5000/17656 (28%)]	Loss: 0.001770
# Training Epoch: 15 [6000/17656 (34%)]	Loss: 0.006618
# Training Epoch: 15 [7000/17656 (40%)]	Loss: 0.002413
# Training Epoch: 15 [8000/17656 (45%)]	Loss: 0.002536
# Training Epoch: 15 [9000/17656 (51%)]	Loss: 0.002603
# Training Epoch: 15 [10000/17656 (57%)]	Loss: 0.002785
# Training Epoch: 15 [11000/17656 (62%)]	Loss: 0.003397
# Training Epoch: 15 [12000/17656 (68%)]	Loss: 0.001714
# Training Epoch: 15 [13000/17656 (74%)]	Loss: 0.030909
# Training Epoch: 15 [14000/17656 (79%)]	Loss: 0.064413
# Training Epoch: 15 [15000/17656 (85%)]	Loss: 0.018304
# Training Epoch: 15 [16000/17656 (91%)]	Loss: 0.011922
# Training Epoch: 15 [17000/17656 (96%)]	Loss: 0.011738
# Validating...
# Validation Epoch: 15 [1000/4414 (23%)]	Loss: 1.097101
# Validation Epoch: 15 [2000/4414 (45%)]	Loss: 1.113049
# Validation Epoch: 15 [3000/4414 (68%)]	Loss: 1.256732
# Validation Epoch: 15 [4000/4414 (90%)]	Loss: 1.063646
# Training Loss: 0.01109966 	Validation Loss 1.11288350 	Training Accuracy 99.638% 	Validation Accuracy 75.850%
#
# EPOCH 16:
# Training...
# Training Epoch: 16 [1000/17656 (6%)]	Loss: 0.031849
# Training Epoch: 16 [2000/17656 (11%)]	Loss: 0.018949
# Training Epoch: 16 [3000/17656 (17%)]	Loss: 0.008676
# Training Epoch: 16 [4000/17656 (23%)]	Loss: 0.010558
# Training Epoch: 16 [5000/17656 (28%)]	Loss: 0.002970
# Training Epoch: 16 [6000/17656 (34%)]	Loss: 0.002044
# Training Epoch: 16 [7000/17656 (40%)]	Loss: 0.002615
# Training Epoch: 16 [8000/17656 (45%)]	Loss: 0.001634
# Training Epoch: 16 [9000/17656 (51%)]	Loss: 0.002755
# Training Epoch: 16 [10000/17656 (57%)]	Loss: 0.014350
# Training Epoch: 16 [11000/17656 (62%)]	Loss: 0.016379
# Training Epoch: 16 [12000/17656 (68%)]	Loss: 0.070421
# Training Epoch: 16 [13000/17656 (74%)]	Loss: 0.043552
# Training Epoch: 16 [14000/17656 (79%)]	Loss: 0.024475
# Training Epoch: 16 [15000/17656 (85%)]	Loss: 0.036463
# Training Epoch: 16 [16000/17656 (91%)]	Loss: 0.026075
# Training Epoch: 16 [17000/17656 (96%)]	Loss: 0.018933
# Validating...
# Validation Epoch: 16 [1000/4414 (23%)]	Loss: 1.118722
# Validation Epoch: 16 [2000/4414 (45%)]	Loss: 1.108639
# Validation Epoch: 16 [3000/4414 (68%)]	Loss: 1.242315
# Validation Epoch: 16 [4000/4414 (90%)]	Loss: 1.106555
# Training Loss: 0.01918989 	Validation Loss 1.12564599 	Training Accuracy 99.513% 	Validation Accuracy 76.552%
#
# EPOCH 17:
# Training...
# Training Epoch: 17 [1000/17656 (6%)]	Loss: 0.010767
# Training Epoch: 17 [2000/17656 (11%)]	Loss: 0.003803
# Training Epoch: 17 [3000/17656 (17%)]	Loss: 0.003459
# Training Epoch: 17 [4000/17656 (23%)]	Loss: 0.002558
# Training Epoch: 17 [5000/17656 (28%)]	Loss: 0.002255
# Training Epoch: 17 [6000/17656 (34%)]	Loss: 0.001767
# Training Epoch: 17 [7000/17656 (40%)]	Loss: 0.001314
# Training Epoch: 17 [8000/17656 (45%)]	Loss: 0.001360
# Training Epoch: 17 [9000/17656 (51%)]	Loss: 0.001403
# Training Epoch: 17 [10000/17656 (57%)]	Loss: 0.001509
# Training Epoch: 17 [11000/17656 (62%)]	Loss: 0.001060
# Training Epoch: 17 [12000/17656 (68%)]	Loss: 0.001389
# Training Epoch: 17 [13000/17656 (74%)]	Loss: 0.000903
# Training Epoch: 17 [14000/17656 (79%)]	Loss: 0.000955
# Training Epoch: 17 [15000/17656 (85%)]	Loss: 0.001074
# Training Epoch: 17 [16000/17656 (91%)]	Loss: 0.000904
# Training Epoch: 17 [17000/17656 (96%)]	Loss: 0.000637
# Validating...
# Validation Epoch: 17 [1000/4414 (23%)]	Loss: 1.124680
# Validation Epoch: 17 [2000/4414 (45%)]	Loss: 1.149152
# Validation Epoch: 17 [3000/4414 (68%)]	Loss: 1.281107
# Validation Epoch: 17 [4000/4414 (90%)]	Loss: 1.117171
# Training Loss: 0.00212524 	Validation Loss 1.14904320 	Training Accuracy 99.989% 	Validation Accuracy 77.390%
#
# EPOCH 18:
# Training...
# Training Epoch: 18 [1000/17656 (6%)]	Loss: 0.000427
# Training Epoch: 18 [2000/17656 (11%)]	Loss: 0.000439
# Training Epoch: 18 [3000/17656 (17%)]	Loss: 0.000491
# Training Epoch: 18 [4000/17656 (23%)]	Loss: 0.000445
# Training Epoch: 18 [5000/17656 (28%)]	Loss: 0.000442
# Training Epoch: 18 [6000/17656 (34%)]	Loss: 0.000335
# Training Epoch: 18 [7000/17656 (40%)]	Loss: 0.000393
# Training Epoch: 18 [8000/17656 (45%)]	Loss: 0.000412
# Training Epoch: 18 [9000/17656 (51%)]	Loss: 0.000413
# Training Epoch: 18 [10000/17656 (57%)]	Loss: 0.000440
# Training Epoch: 18 [11000/17656 (62%)]	Loss: 0.000368
# Training Epoch: 18 [12000/17656 (68%)]	Loss: 0.000351
# Training Epoch: 18 [13000/17656 (74%)]	Loss: 0.000476
# Training Epoch: 18 [14000/17656 (79%)]	Loss: 0.000362
# Training Epoch: 18 [15000/17656 (85%)]	Loss: 0.000371
# Training Epoch: 18 [16000/17656 (91%)]	Loss: 0.000304
# Training Epoch: 18 [17000/17656 (96%)]	Loss: 0.000329
# Validating...
# Validation Epoch: 18 [1000/4414 (23%)]	Loss: 1.171440
# Validation Epoch: 18 [2000/4414 (45%)]	Loss: 1.203829
# Validation Epoch: 18 [3000/4414 (68%)]	Loss: 1.322434
# Validation Epoch: 18 [4000/4414 (90%)]	Loss: 1.170529
# Training Loss: 0.00039863 	Validation Loss 1.19837202 	Training Accuracy 100.000% 	Validation Accuracy 77.503%
#
# EPOCH 19:
# Training...
# Training Epoch: 19 [1000/17656 (6%)]	Loss: 0.000249
# Training Epoch: 19 [2000/17656 (11%)]	Loss: 0.000232
# Training Epoch: 19 [3000/17656 (17%)]	Loss: 0.000214
# Training Epoch: 19 [4000/17656 (23%)]	Loss: 0.000229
# Training Epoch: 19 [5000/17656 (28%)]	Loss: 0.000254
# Training Epoch: 19 [6000/17656 (34%)]	Loss: 0.000205
# Training Epoch: 19 [7000/17656 (40%)]	Loss: 0.000228
# Training Epoch: 19 [8000/17656 (45%)]	Loss: 0.000208
# Training Epoch: 19 [9000/17656 (51%)]	Loss: 0.000208
# Training Epoch: 19 [10000/17656 (57%)]	Loss: 0.000192
# Training Epoch: 19 [11000/17656 (62%)]	Loss: 0.000196
# Training Epoch: 19 [12000/17656 (68%)]	Loss: 0.000206
# Training Epoch: 19 [13000/17656 (74%)]	Loss: 0.000201
# Training Epoch: 19 [14000/17656 (79%)]	Loss: 0.000182
# Training Epoch: 19 [15000/17656 (85%)]	Loss: 0.000171
# Training Epoch: 19 [16000/17656 (91%)]	Loss: 0.000196
# Training Epoch: 19 [17000/17656 (96%)]	Loss: 0.000189
# Validating...
# Validation Epoch: 19 [1000/4414 (23%)]	Loss: 1.245917
# Validation Epoch: 19 [2000/4414 (45%)]	Loss: 1.271219
# Validation Epoch: 19 [3000/4414 (68%)]	Loss: 1.391785
# Validation Epoch: 19 [4000/4414 (90%)]	Loss: 1.214011
# Training Loss: 0.00020898 	Validation Loss 1.25880066 	Training Accuracy 100.000% 	Validation Accuracy 77.322%
#
# EPOCH 20:
# Training...
# Training Epoch: 20 [1000/17656 (6%)]	Loss: 0.000126
# Training Epoch: 20 [2000/17656 (11%)]	Loss: 0.000127
# Training Epoch: 20 [3000/17656 (17%)]	Loss: 0.000133
# Training Epoch: 20 [4000/17656 (23%)]	Loss: 0.000107
# Training Epoch: 20 [5000/17656 (28%)]	Loss: 0.000134
# Training Epoch: 20 [6000/17656 (34%)]	Loss: 0.000118
# Training Epoch: 20 [7000/17656 (40%)]	Loss: 0.000122
# Training Epoch: 20 [8000/17656 (45%)]	Loss: 0.000118
# Training Epoch: 20 [9000/17656 (51%)]	Loss: 0.000100
# Training Epoch: 20 [10000/17656 (57%)]	Loss: 0.000089
# Training Epoch: 20 [11000/17656 (62%)]	Loss: 0.000106
# Training Epoch: 20 [12000/17656 (68%)]	Loss: 0.000106
# Training Epoch: 20 [13000/17656 (74%)]	Loss: 0.000103
# Training Epoch: 20 [14000/17656 (79%)]	Loss: 0.000107
# Training Epoch: 20 [15000/17656 (85%)]	Loss: 0.000104
# Training Epoch: 20 [16000/17656 (91%)]	Loss: 0.000096
# Training Epoch: 20 [17000/17656 (96%)]	Loss: 0.000107
# Validating...
# Validation Epoch: 20 [1000/4414 (23%)]	Loss: 1.311151
# Validation Epoch: 20 [2000/4414 (45%)]	Loss: 1.346919
# Validation Epoch: 20 [3000/4414 (68%)]	Loss: 1.454727
# Validation Epoch: 20 [4000/4414 (90%)]	Loss: 1.277882
# Training Loss: 0.00011086 	Validation Loss 1.32398511 	Training Accuracy 100.000% 	Validation Accuracy 77.594%
#
# EPOCH 21:
# Training...
# Training Epoch: 21 [1000/17656 (6%)]	Loss: 0.000064
# Training Epoch: 21 [2000/17656 (11%)]	Loss: 0.000054
# Training Epoch: 21 [3000/17656 (17%)]	Loss: 0.000063
# Training Epoch: 21 [4000/17656 (23%)]	Loss: 0.000056
# Training Epoch: 21 [5000/17656 (28%)]	Loss: 0.000059
# Training Epoch: 21 [6000/17656 (34%)]	Loss: 0.000052
# Training Epoch: 21 [7000/17656 (40%)]	Loss: 0.000062
# Training Epoch: 21 [8000/17656 (45%)]	Loss: 0.000055
# Training Epoch: 21 [9000/17656 (51%)]	Loss: 0.000054
# Training Epoch: 21 [10000/17656 (57%)]	Loss: 0.000046
# Training Epoch: 21 [11000/17656 (62%)]	Loss: 0.000053
# Training Epoch: 21 [12000/17656 (68%)]	Loss: 0.000053
# Training Epoch: 21 [13000/17656 (74%)]	Loss: 0.000047
# Training Epoch: 21 [14000/17656 (79%)]	Loss: 0.000045
# Training Epoch: 21 [15000/17656 (85%)]	Loss: 0.000054
# Training Epoch: 21 [16000/17656 (91%)]	Loss: 0.000055
# Training Epoch: 21 [17000/17656 (96%)]	Loss: 0.000042
# Validating...
# Validation Epoch: 21 [1000/4414 (23%)]	Loss: 1.398504
# Validation Epoch: 21 [2000/4414 (45%)]	Loss: 1.403975
# Validation Epoch: 21 [3000/4414 (68%)]	Loss: 1.549309
# Validation Epoch: 21 [4000/4414 (90%)]	Loss: 1.368582
# Training Loss: 0.00005348 	Validation Loss 1.40465435 	Training Accuracy 100.000% 	Validation Accuracy 77.435%
#
# EPOCH 22:
# Training...
# Training Epoch: 22 [1000/17656 (6%)]	Loss: 0.000026
# Training Epoch: 22 [2000/17656 (11%)]	Loss: 0.000034
# Training Epoch: 22 [3000/17656 (17%)]	Loss: 0.000027
# Training Epoch: 22 [4000/17656 (23%)]	Loss: 0.000030
# Training Epoch: 22 [5000/17656 (28%)]	Loss: 0.000027
# Training Epoch: 22 [6000/17656 (34%)]	Loss: 0.000022
# Training Epoch: 22 [7000/17656 (40%)]	Loss: 0.000023
# Training Epoch: 22 [8000/17656 (45%)]	Loss: 0.000025
# Training Epoch: 22 [9000/17656 (51%)]	Loss: 0.000026
# Training Epoch: 22 [10000/17656 (57%)]	Loss: 0.000021
# Training Epoch: 22 [11000/17656 (62%)]	Loss: 0.000023
# Training Epoch: 22 [12000/17656 (68%)]	Loss: 0.000021
# Training Epoch: 22 [13000/17656 (74%)]	Loss: 0.000022
# Training Epoch: 22 [14000/17656 (79%)]	Loss: 0.000021
# Training Epoch: 22 [15000/17656 (85%)]	Loss: 0.000021
# Training Epoch: 22 [16000/17656 (91%)]	Loss: 0.000021
# Training Epoch: 22 [17000/17656 (96%)]	Loss: 0.000022
# Validating...
# Validation Epoch: 22 [1000/4414 (23%)]	Loss: 1.512211
# Validation Epoch: 22 [2000/4414 (45%)]	Loss: 1.515316
# Validation Epoch: 22 [3000/4414 (68%)]	Loss: 1.694801
# Validation Epoch: 22 [4000/4414 (90%)]	Loss: 1.472297
# Training Loss: 0.00002398 	Validation Loss 1.51667216 	Training Accuracy 100.000% 	Validation Accuracy 77.277%
#
# EPOCH 23:
# Training...
# Training Epoch: 23 [1000/17656 (6%)]	Loss: 0.000013
# Training Epoch: 23 [2000/17656 (11%)]	Loss: 0.000011
# Training Epoch: 23 [3000/17656 (17%)]	Loss: 0.000010
# Training Epoch: 23 [4000/17656 (23%)]	Loss: 0.000011
# Training Epoch: 23 [5000/17656 (28%)]	Loss: 0.000011
# Training Epoch: 23 [6000/17656 (34%)]	Loss: 0.000011
# Training Epoch: 23 [7000/17656 (40%)]	Loss: 0.000011
# Training Epoch: 23 [8000/17656 (45%)]	Loss: 0.000010
# Training Epoch: 23 [9000/17656 (51%)]	Loss: 0.000009
# Training Epoch: 23 [10000/17656 (57%)]	Loss: 0.000010
# Training Epoch: 23 [11000/17656 (62%)]	Loss: 0.000009
# Training Epoch: 23 [12000/17656 (68%)]	Loss: 0.000008
# Training Epoch: 23 [13000/17656 (74%)]	Loss: 0.000009
# Training Epoch: 23 [14000/17656 (79%)]	Loss: 0.000008
# Training Epoch: 23 [15000/17656 (85%)]	Loss: 0.000009
# Training Epoch: 23 [16000/17656 (91%)]	Loss: 0.000009
# Training Epoch: 23 [17000/17656 (96%)]	Loss: 0.000008
# Validating...
# Validation Epoch: 23 [1000/4414 (23%)]	Loss: 1.610676
# Validation Epoch: 23 [2000/4414 (45%)]	Loss: 1.630482
# Validation Epoch: 23 [3000/4414 (68%)]	Loss: 1.772669
# Validation Epoch: 23 [4000/4414 (90%)]	Loss: 1.580154
# Training Loss: 0.00000980 	Validation Loss 1.61743418 	Training Accuracy 100.000% 	Validation Accuracy 77.345%
#
# EPOCH 24:
# Training...
# Training Epoch: 24 [1000/17656 (6%)]	Loss: 0.000005
# Training Epoch: 24 [2000/17656 (11%)]	Loss: 0.000005
# Training Epoch: 24 [3000/17656 (17%)]	Loss: 0.000004
# Training Epoch: 24 [4000/17656 (23%)]	Loss: 0.000004
# Training Epoch: 24 [5000/17656 (28%)]	Loss: 0.000004
# Training Epoch: 24 [6000/17656 (34%)]	Loss: 0.000004
# Training Epoch: 24 [7000/17656 (40%)]	Loss: 0.000004
# Training Epoch: 24 [8000/17656 (45%)]	Loss: 0.000004
# Training Epoch: 24 [9000/17656 (51%)]	Loss: 0.000004
# Training Epoch: 24 [10000/17656 (57%)]	Loss: 0.000004
# Training Epoch: 24 [11000/17656 (62%)]	Loss: 0.000004
# Training Epoch: 24 [12000/17656 (68%)]	Loss: 0.000004
# Training Epoch: 24 [13000/17656 (74%)]	Loss: 0.000003
# Training Epoch: 24 [14000/17656 (79%)]	Loss: 0.000004
# Training Epoch: 24 [15000/17656 (85%)]	Loss: 0.000004
# Training Epoch: 24 [16000/17656 (91%)]	Loss: 0.000003
# Training Epoch: 24 [17000/17656 (96%)]	Loss: 0.000003
# Validating...
# Validation Epoch: 24 [1000/4414 (23%)]	Loss: 1.729162
# Validation Epoch: 24 [2000/4414 (45%)]	Loss: 1.722031
# Validation Epoch: 24 [3000/4414 (68%)]	Loss: 1.914105
# Validation Epoch: 24 [4000/4414 (90%)]	Loss: 1.657642
# Training Loss: 0.00000390 	Validation Loss 1.72242921 	Training Accuracy 100.000% 	Validation Accuracy 77.209%
#
# EPOCH 25:
# Training...
# Training Epoch: 25 [1000/17656 (6%)]	Loss: 0.000002
# Training Epoch: 25 [2000/17656 (11%)]	Loss: 0.000002
# Training Epoch: 25 [3000/17656 (17%)]	Loss: 0.000002
# Training Epoch: 25 [4000/17656 (23%)]	Loss: 0.000002
# Training Epoch: 25 [5000/17656 (28%)]	Loss: 0.000002
# Training Epoch: 25 [6000/17656 (34%)]	Loss: 0.000002
# Training Epoch: 25 [7000/17656 (40%)]	Loss: 0.000002
# Training Epoch: 25 [8000/17656 (45%)]	Loss: 0.000002
# Training Epoch: 25 [9000/17656 (51%)]	Loss: 0.000002
# Training Epoch: 25 [10000/17656 (57%)]	Loss: 0.000001
# Training Epoch: 25 [11000/17656 (62%)]	Loss: 0.000001
# Training Epoch: 25 [12000/17656 (68%)]	Loss: 0.000001
# Training Epoch: 25 [13000/17656 (74%)]	Loss: 0.000001
# Training Epoch: 25 [14000/17656 (79%)]	Loss: 0.000001
# Training Epoch: 25 [15000/17656 (85%)]	Loss: 0.000001
# Training Epoch: 25 [16000/17656 (91%)]	Loss: 0.000001
# Training Epoch: 25 [17000/17656 (96%)]	Loss: 0.000001
# Validating...
# Validation Epoch: 25 [1000/4414 (23%)]	Loss: 1.834963
# Validation Epoch: 25 [2000/4414 (45%)]	Loss: 1.847430
# Validation Epoch: 25 [3000/4414 (68%)]	Loss: 2.027448
# Validation Epoch: 25 [4000/4414 (90%)]	Loss: 1.780931
# Training Loss: 0.00000152 	Validation Loss 1.83453983 	Training Accuracy 100.000% 	Validation Accuracy 77.141%
#
# EPOCH 26:
# Training...
# Training Epoch: 26 [1000/17656 (6%)]	Loss: 0.000001
# Training Epoch: 26 [2000/17656 (11%)]	Loss: 0.000001
# Training Epoch: 26 [3000/17656 (17%)]	Loss: 0.000001
# Training Epoch: 26 [4000/17656 (23%)]	Loss: 0.000001
# Training Epoch: 26 [5000/17656 (28%)]	Loss: 0.000001
# Training Epoch: 26 [6000/17656 (34%)]	Loss: 0.000001
# Training Epoch: 26 [7000/17656 (40%)]	Loss: 0.000001
# Training Epoch: 26 [8000/17656 (45%)]	Loss: 0.000001
# Training Epoch: 26 [9000/17656 (51%)]	Loss: 0.000001
# Training Epoch: 26 [10000/17656 (57%)]	Loss: 0.000001
# Training Epoch: 26 [11000/17656 (62%)]	Loss: 0.000001
# Training Epoch: 26 [12000/17656 (68%)]	Loss: 0.000001
# Training Epoch: 26 [13000/17656 (74%)]	Loss: 0.000001
# Training Epoch: 26 [14000/17656 (79%)]	Loss: 0.000000
# Training Epoch: 26 [15000/17656 (85%)]	Loss: 0.000000
# Training Epoch: 26 [16000/17656 (91%)]	Loss: 0.000001
# Training Epoch: 26 [17000/17656 (96%)]	Loss: 0.000001
# Validating...
# Validation Epoch: 26 [1000/4414 (23%)]	Loss: 1.956742
# Validation Epoch: 26 [2000/4414 (45%)]	Loss: 1.974035
# Validation Epoch: 26 [3000/4414 (68%)]	Loss: 2.157605
# Validation Epoch: 26 [4000/4414 (90%)]	Loss: 1.895974
# Training Loss: 0.00000060 	Validation Loss 1.95367100 	Training Accuracy 100.000% 	Validation Accuracy 77.164%
#
# EPOCH 27:
# Training...
# Training Epoch: 27 [1000/17656 (6%)]	Loss: 0.000000
# Training Epoch: 27 [2000/17656 (11%)]	Loss: 0.000000
# Training Epoch: 27 [3000/17656 (17%)]	Loss: 0.000000
# Training Epoch: 27 [4000/17656 (23%)]	Loss: 0.000000
# Training Epoch: 27 [5000/17656 (28%)]	Loss: 0.000000
# Training Epoch: 27 [6000/17656 (34%)]	Loss: 0.000000
# Training Epoch: 27 [7000/17656 (40%)]	Loss: 0.000000
# Training Epoch: 27 [8000/17656 (45%)]	Loss: 0.000000
# Training Epoch: 27 [9000/17656 (51%)]	Loss: 0.000000
# Training Epoch: 27 [10000/17656 (57%)]	Loss: 0.000000
# Training Epoch: 27 [11000/17656 (62%)]	Loss: 0.000000
# Training Epoch: 27 [12000/17656 (68%)]	Loss: 0.000000
# Training Epoch: 27 [13000/17656 (74%)]	Loss: 0.000000
# Training Epoch: 27 [14000/17656 (79%)]	Loss: 0.000000
# Training Epoch: 27 [15000/17656 (85%)]	Loss: 0.000000
# Training Epoch: 27 [16000/17656 (91%)]	Loss: 0.000000
# Training Epoch: 27 [17000/17656 (96%)]	Loss: 0.000000
# Validating...
# Validation Epoch: 27 [1000/4414 (23%)]	Loss: 2.050611
# Validation Epoch: 27 [2000/4414 (45%)]	Loss: 2.062982
# Validation Epoch: 27 [3000/4414 (68%)]	Loss: 2.262753
# Validation Epoch: 27 [4000/4414 (90%)]	Loss: 1.997411
# Training Loss: 0.00000024 	Validation Loss 2.04984486 	Training Accuracy 100.000% 	Validation Accuracy 76.937%
#
# EPOCH 28:
# Training...
# Training Epoch: 28 [1000/17656 (6%)]	Loss: 0.000000
# Training Epoch: 28 [2000/17656 (11%)]	Loss: 0.000000
# Training Epoch: 28 [3000/17656 (17%)]	Loss: 0.000000
# Training Epoch: 28 [4000/17656 (23%)]	Loss: 0.000000
# Training Epoch: 28 [5000/17656 (28%)]	Loss: 0.000000
# Training Epoch: 28 [6000/17656 (34%)]	Loss: 0.000000
# Training Epoch: 28 [7000/17656 (40%)]	Loss: 0.000000
# Training Epoch: 28 [8000/17656 (45%)]	Loss: 0.000000
# Training Epoch: 28 [9000/17656 (51%)]	Loss: 0.000000
# Training Epoch: 28 [10000/17656 (57%)]	Loss: 0.000000
# Training Epoch: 28 [11000/17656 (62%)]	Loss: 0.000000
# Training Epoch: 28 [12000/17656 (68%)]	Loss: 0.000000
# Training Epoch: 28 [13000/17656 (74%)]	Loss: 0.000000
# Training Epoch: 28 [14000/17656 (79%)]	Loss: 0.000000
# Training Epoch: 28 [15000/17656 (85%)]	Loss: 0.000000
# Training Epoch: 28 [16000/17656 (91%)]	Loss: 0.000000
# Training Epoch: 28 [17000/17656 (96%)]	Loss: 0.000000
# Validating...
# Validation Epoch: 28 [1000/4414 (23%)]	Loss: 2.176831
# Validation Epoch: 28 [2000/4414 (45%)]	Loss: 2.184656
# Validation Epoch: 28 [3000/4414 (68%)]	Loss: 2.380191
# Validation Epoch: 28 [4000/4414 (90%)]	Loss: 2.131533
# Training Loss: 0.00000010 	Validation Loss 2.16951814 	Training Accuracy 100.000% 	Validation Accuracy 76.733%
#
# EPOCH 29:
# Training...
# Training Epoch: 29 [1000/17656 (6%)]	Loss: 0.000000
# Training Epoch: 29 [2000/17656 (11%)]	Loss: 0.000000
# Training Epoch: 29 [3000/17656 (17%)]	Loss: 0.000000
# Training Epoch: 29 [4000/17656 (23%)]	Loss: 0.000000
# Training Epoch: 29 [5000/17656 (28%)]	Loss: 0.000000
# Training Epoch: 29 [6000/17656 (34%)]	Loss: 0.000000
# Training Epoch: 29 [7000/17656 (40%)]	Loss: 0.000000
# Training Epoch: 29 [8000/17656 (45%)]	Loss: 0.000000
# Training Epoch: 29 [9000/17656 (51%)]	Loss: 0.000000
# Training Epoch: 29 [10000/17656 (57%)]	Loss: 0.000000
# Training Epoch: 29 [11000/17656 (62%)]	Loss: 0.000000
# Training Epoch: 29 [12000/17656 (68%)]	Loss: 0.000000
# Training Epoch: 29 [13000/17656 (74%)]	Loss: 0.000000
# Training Epoch: 29 [14000/17656 (79%)]	Loss: 0.000000
# Training Epoch: 29 [15000/17656 (85%)]	Loss: 0.000000
# Training Epoch: 29 [16000/17656 (91%)]	Loss: 0.000000
# Training Epoch: 29 [17000/17656 (96%)]	Loss: 0.000000
# Validating...
# Validation Epoch: 29 [1000/4414 (23%)]	Loss: 2.257153
# Validation Epoch: 29 [2000/4414 (45%)]	Loss: 2.285985
# Validation Epoch: 29 [3000/4414 (68%)]	Loss: 2.516562
# Validation Epoch: 29 [4000/4414 (90%)]	Loss: 2.245779
# Training Loss: 0.00000004 	Validation Loss 2.27703661 	Training Accuracy 100.000% 	Validation Accuracy 76.914%
#
# EPOCH 30:
# Training...
# Training Epoch: 30 [1000/17656 (6%)]	Loss: 0.000000
# Training Epoch: 30 [2000/17656 (11%)]	Loss: 0.000000
# Training Epoch: 30 [3000/17656 (17%)]	Loss: 0.000000
# Training Epoch: 30 [4000/17656 (23%)]	Loss: 0.000000
# Training Epoch: 30 [5000/17656 (28%)]	Loss: 0.000000
# Training Epoch: 30 [6000/17656 (34%)]	Loss: 0.000000
# Training Epoch: 30 [7000/17656 (40%)]	Loss: 0.000000
# Training Epoch: 30 [8000/17656 (45%)]	Loss: 0.000000
# Training Epoch: 30 [9000/17656 (51%)]	Loss: 0.000000
# Training Epoch: 30 [10000/17656 (57%)]	Loss: 0.000000
# Training Epoch: 30 [11000/17656 (62%)]	Loss: 0.000000
# Training Epoch: 30 [12000/17656 (68%)]	Loss: 0.000000
# Training Epoch: 30 [13000/17656 (74%)]	Loss: 0.000000
# Training Epoch: 30 [14000/17656 (79%)]	Loss: 0.000000
# Training Epoch: 30 [15000/17656 (85%)]	Loss: 0.000000
# Training Epoch: 30 [16000/17656 (91%)]	Loss: 0.000000
# Training Epoch: 30 [17000/17656 (96%)]	Loss: 0.000000
# Validating...
# Validation Epoch: 30 [1000/4414 (23%)]	Loss: 2.317247
# Validation Epoch: 30 [2000/4414 (45%)]	Loss: 2.348144
# Validation Epoch: 30 [3000/4414 (68%)]	Loss: 2.589987
# Validation Epoch: 30 [4000/4414 (90%)]	Loss: 2.290273
# Training Loss: 0.00000001 	Validation Loss 2.33474029 	Training Accuracy 100.000% 	Validation Accuracy 76.507%
#
# EPOCH 31:
# Training...
# Training Epoch: 31 [1000/17656 (6%)]	Loss: 0.000000
# Training Epoch: 31 [2000/17656 (11%)]	Loss: 0.000000
# Training Epoch: 31 [3000/17656 (17%)]	Loss: 0.000000
# Training Epoch: 31 [4000/17656 (23%)]	Loss: 0.000000
# Training Epoch: 31 [5000/17656 (28%)]	Loss: 0.000000
# Training Epoch: 31 [6000/17656 (34%)]	Loss: 0.000000
# Training Epoch: 31 [7000/17656 (40%)]	Loss: 0.000000
# Training Epoch: 31 [8000/17656 (45%)]	Loss: 0.000000
# Training Epoch: 31 [9000/17656 (51%)]	Loss: 0.000000
# Training Epoch: 31 [10000/17656 (57%)]	Loss: 0.000000
# Training Epoch: 31 [11000/17656 (62%)]	Loss: 0.000000
# Training Epoch: 31 [12000/17656 (68%)]	Loss: 0.000000
# Training Epoch: 31 [13000/17656 (74%)]	Loss: 0.000000
# Training Epoch: 31 [14000/17656 (79%)]	Loss: 0.000000
# Training Epoch: 31 [15000/17656 (85%)]	Loss: 0.000000
# Training Epoch: 31 [16000/17656 (91%)]	Loss: 0.000000
# Training Epoch: 31 [17000/17656 (96%)]	Loss: 0.000000
# Validating...
# Validation Epoch: 31 [1000/4414 (23%)]	Loss: 2.352282
# Validation Epoch: 31 [2000/4414 (45%)]	Loss: 2.381545
# Validation Epoch: 31 [3000/4414 (68%)]	Loss: 2.590317
# Validation Epoch: 31 [4000/4414 (90%)]	Loss: 2.291718
# Training Loss: 0.00000000 	Validation Loss 2.35666559 	Training Accuracy 100.000% 	Validation Accuracy 76.914%
#
# EPOCH 32:
# Training...
# Training Epoch: 32 [1000/17656 (6%)]	Loss: 0.000000
# Training Epoch: 32 [2000/17656 (11%)]	Loss: 0.000000
# Training Epoch: 32 [3000/17656 (17%)]	Loss: 0.000000
# Training Epoch: 32 [4000/17656 (23%)]	Loss: 0.000000
# Training Epoch: 32 [5000/17656 (28%)]	Loss: 0.000000
# Training Epoch: 32 [6000/17656 (34%)]	Loss: 0.000000
# Training Epoch: 32 [7000/17656 (40%)]	Loss: 0.000000
# Training Epoch: 32 [8000/17656 (45%)]	Loss: 0.000000
# Training Epoch: 32 [9000/17656 (51%)]	Loss: 0.000000
# Training Epoch: 32 [10000/17656 (57%)]	Loss: 0.000000
# Training Epoch: 32 [11000/17656 (62%)]	Loss: 0.000000
# Training Epoch: 32 [12000/17656 (68%)]	Loss: 0.085419
# Training Epoch: 32 [13000/17656 (74%)]	Loss: 0.204290
# Training Epoch: 32 [14000/17656 (79%)]	Loss: 0.027919
# Training Epoch: 32 [15000/17656 (85%)]	Loss: 0.022286
# Training Epoch: 32 [16000/17656 (91%)]	Loss: 0.017437
# Training Epoch: 32 [17000/17656 (96%)]	Loss: 0.027982
# Validating...
# Validation Epoch: 32 [1000/4414 (23%)]	Loss: 1.258011
# Validation Epoch: 32 [2000/4414 (45%)]	Loss: 1.386209
# Validation Epoch: 32 [3000/4414 (68%)]	Loss: 1.453232
# Validation Epoch: 32 [4000/4414 (90%)]	Loss: 1.290228
# Training Loss: 0.02295665 	Validation Loss 1.32320833 	Training Accuracy 99.377% 	Validation Accuracy 76.053%
#
# EPOCH 33:
# Training...
# Training Epoch: 33 [1000/17656 (6%)]	Loss: 0.016005
# Training Epoch: 33 [2000/17656 (11%)]	Loss: 0.007803
# Training Epoch: 33 [3000/17656 (17%)]	Loss: 0.007551
# Training Epoch: 33 [4000/17656 (23%)]	Loss: 0.004338
# Training Epoch: 33 [5000/17656 (28%)]	Loss: 0.015300
# Training Epoch: 33 [6000/17656 (34%)]	Loss: 0.022014
# Training Epoch: 33 [7000/17656 (40%)]	Loss: 0.003277
# Training Epoch: 33 [8000/17656 (45%)]	Loss: 0.002069
# Training Epoch: 33 [9000/17656 (51%)]	Loss: 0.001406
# Training Epoch: 33 [10000/17656 (57%)]	Loss: 0.001073
# Training Epoch: 33 [11000/17656 (62%)]	Loss: 0.000593
# Training Epoch: 33 [12000/17656 (68%)]	Loss: 0.000397
# Training Epoch: 33 [13000/17656 (74%)]	Loss: 0.002967
# Training Epoch: 33 [14000/17656 (79%)]	Loss: 0.021619
# Training Epoch: 33 [15000/17656 (85%)]	Loss: 0.063709
# Training Epoch: 33 [16000/17656 (91%)]	Loss: 0.018432
# Training Epoch: 33 [17000/17656 (96%)]	Loss: 0.017254
# Validating...
# Validation Epoch: 33 [1000/4414 (23%)]	Loss: 1.524602
# Validation Epoch: 33 [2000/4414 (45%)]	Loss: 1.641919
# Validation Epoch: 33 [3000/4414 (68%)]	Loss: 1.740169
# Validation Epoch: 33 [4000/4414 (90%)]	Loss: 1.475349
# Training Loss: 0.01297425 	Validation Loss 1.56248365 	Training Accuracy 99.592% 	Validation Accuracy 75.147%
#
# EPOCH 34:
# Training...
# Training Epoch: 34 [1000/17656 (6%)]	Loss: 0.043244
# Training Epoch: 34 [2000/17656 (11%)]	Loss: 0.001642
# Training Epoch: 34 [3000/17656 (17%)]	Loss: 0.002001
# Training Epoch: 34 [4000/17656 (23%)]	Loss: 0.001679
# Training Epoch: 34 [5000/17656 (28%)]	Loss: 0.001400
# Training Epoch: 34 [6000/17656 (34%)]	Loss: 0.043144
# Training Epoch: 34 [7000/17656 (40%)]	Loss: 0.005596
# Training Epoch: 34 [8000/17656 (45%)]	Loss: 0.022702
# Training Epoch: 34 [9000/17656 (51%)]	Loss: 0.005918
# Training Epoch: 34 [10000/17656 (57%)]	Loss: 0.001965
# Training Epoch: 34 [11000/17656 (62%)]	Loss: 0.003347
# Training Epoch: 34 [12000/17656 (68%)]	Loss: 0.014892
# Training Epoch: 34 [13000/17656 (74%)]	Loss: 0.008670
# Training Epoch: 34 [14000/17656 (79%)]	Loss: 0.034977
# Training Epoch: 34 [15000/17656 (85%)]	Loss: 0.022995
# Training Epoch: 34 [16000/17656 (91%)]	Loss: 0.017799
# Training Epoch: 34 [17000/17656 (96%)]	Loss: 0.044646
# Validating...
# Validation Epoch: 34 [1000/4414 (23%)]	Loss: 1.318869
# Validation Epoch: 34 [2000/4414 (45%)]	Loss: 1.352769
# Validation Epoch: 34 [3000/4414 (68%)]	Loss: 1.456167
# Validation Epoch: 34 [4000/4414 (90%)]	Loss: 1.272890
# Training Loss: 0.01702916 	Validation Loss 1.33610617 	Training Accuracy 99.547% 	Validation Accuracy 75.487%
#
# EPOCH 35:
# Training...
# Training Epoch: 35 [1000/17656 (6%)]	Loss: 0.026675
# Training Epoch: 35 [2000/17656 (11%)]	Loss: 0.014496
# Training Epoch: 35 [3000/17656 (17%)]	Loss: 0.002313
# Training Epoch: 35 [4000/17656 (23%)]	Loss: 0.001966
# Training Epoch: 35 [5000/17656 (28%)]	Loss: 0.000529
# Training Epoch: 35 [6000/17656 (34%)]	Loss: 0.000642
# Training Epoch: 35 [7000/17656 (40%)]	Loss: 0.002196
# Training Epoch: 35 [8000/17656 (45%)]	Loss: 0.007877
# Training Epoch: 35 [9000/17656 (51%)]	Loss: 0.018745
# Training Epoch: 35 [10000/17656 (57%)]	Loss: 0.062503
# Training Epoch: 35 [11000/17656 (62%)]	Loss: 0.007552
# Training Epoch: 35 [12000/17656 (68%)]	Loss: 0.018575
# Training Epoch: 35 [13000/17656 (74%)]	Loss: 0.018169
# Training Epoch: 35 [14000/17656 (79%)]	Loss: 0.024833
# Training Epoch: 35 [15000/17656 (85%)]	Loss: 0.013949
# Training Epoch: 35 [16000/17656 (91%)]	Loss: 0.011322
# Training Epoch: 35 [17000/17656 (96%)]	Loss: 0.034854
# Validating...
# Validation Epoch: 35 [1000/4414 (23%)]	Loss: 1.502290
# Validation Epoch: 35 [2000/4414 (45%)]	Loss: 1.615076
# Validation Epoch: 35 [3000/4414 (68%)]	Loss: 1.547036
# Validation Epoch: 35 [4000/4414 (90%)]	Loss: 1.495649
# Training Loss: 0.01724323 	Validation Loss 1.52726937 	Training Accuracy 99.468% 	Validation Accuracy 73.493%
#
# EPOCH 36:
# Training...
# Training Epoch: 36 [1000/17656 (6%)]	Loss: 0.021835
# Training Epoch: 36 [2000/17656 (11%)]	Loss: 0.006261
# Training Epoch: 36 [3000/17656 (17%)]	Loss: 0.009150
# Training Epoch: 36 [4000/17656 (23%)]	Loss: 0.021000
# Training Epoch: 36 [5000/17656 (28%)]	Loss: 0.005248
# Training Epoch: 36 [6000/17656 (34%)]	Loss: 0.001462
# Training Epoch: 36 [7000/17656 (40%)]	Loss: 0.003438
# Training Epoch: 36 [8000/17656 (45%)]	Loss: 0.010803
# Training Epoch: 36 [9000/17656 (51%)]	Loss: 0.009758
# Training Epoch: 36 [10000/17656 (57%)]	Loss: 0.009059
# Training Epoch: 36 [11000/17656 (62%)]	Loss: 0.035523
# Training Epoch: 36 [12000/17656 (68%)]	Loss: 0.010086
# Training Epoch: 36 [13000/17656 (74%)]	Loss: 0.002844
# Training Epoch: 36 [14000/17656 (79%)]	Loss: 0.010217
# Training Epoch: 36 [15000/17656 (85%)]	Loss: 0.017417
# Training Epoch: 36 [16000/17656 (91%)]	Loss: 0.026579
# Training Epoch: 36 [17000/17656 (96%)]	Loss: 0.029348
# Validating...
# Validation Epoch: 36 [1000/4414 (23%)]	Loss: 1.485313
# Validation Epoch: 36 [2000/4414 (45%)]	Loss: 1.566625
# Validation Epoch: 36 [3000/4414 (68%)]	Loss: 1.695132
# Validation Epoch: 36 [4000/4414 (90%)]	Loss: 1.430402
# Training Loss: 0.01349061 	Validation Loss 1.52146807 	Training Accuracy 99.541% 	Validation Accuracy 75.804%
#
# EPOCH 37:
# Training...
# Training Epoch: 37 [1000/17656 (6%)]	Loss: 0.008928
# Training Epoch: 37 [2000/17656 (11%)]	Loss: 0.006989
# Training Epoch: 37 [3000/17656 (17%)]	Loss: 0.009063
# Training Epoch: 37 [4000/17656 (23%)]	Loss: 0.010150
# Training Epoch: 37 [5000/17656 (28%)]	Loss: 0.019899
# Training Epoch: 37 [6000/17656 (34%)]	Loss: 0.061854
# Training Epoch: 37 [7000/17656 (40%)]	Loss: 0.017954
# Training Epoch: 37 [8000/17656 (45%)]	Loss: 0.015968
# Training Epoch: 37 [9000/17656 (51%)]	Loss: 0.003110
# Training Epoch: 37 [10000/17656 (57%)]	Loss: 0.001390
# Training Epoch: 37 [11000/17656 (62%)]	Loss: 0.001453
# Training Epoch: 37 [12000/17656 (68%)]	Loss: 0.001987
# Training Epoch: 37 [13000/17656 (74%)]	Loss: 0.000933
# Training Epoch: 37 [14000/17656 (79%)]	Loss: 0.001019
# Training Epoch: 37 [15000/17656 (85%)]	Loss: 0.001065
# Training Epoch: 37 [16000/17656 (91%)]	Loss: 0.002222
# Training Epoch: 37 [17000/17656 (96%)]	Loss: 0.000868
# Validating...
# Validation Epoch: 37 [1000/4414 (23%)]	Loss: 1.616925
# Validation Epoch: 37 [2000/4414 (45%)]	Loss: 1.585538
# Validation Epoch: 37 [3000/4414 (68%)]	Loss: 1.800922
# Validation Epoch: 37 [4000/4414 (90%)]	Loss: 1.425226
# Training Loss: 0.00934146 	Validation Loss 1.58288121 	Training Accuracy 99.728% 	Validation Accuracy 76.552%
#
# EPOCH 38:
# Training...
# Training Epoch: 38 [1000/17656 (6%)]	Loss: 0.000124
# Training Epoch: 38 [2000/17656 (11%)]	Loss: 0.000296
# Training Epoch: 38 [3000/17656 (17%)]	Loss: 0.164007
# Training Epoch: 38 [4000/17656 (23%)]	Loss: 0.028577
# Training Epoch: 38 [5000/17656 (28%)]	Loss: 0.015073
# Training Epoch: 38 [6000/17656 (34%)]	Loss: 0.008963
# Training Epoch: 38 [7000/17656 (40%)]	Loss: 0.006642
# Training Epoch: 38 [8000/17656 (45%)]	Loss: 0.003262
# Training Epoch: 38 [9000/17656 (51%)]	Loss: 0.001902
# Training Epoch: 38 [10000/17656 (57%)]	Loss: 0.008061
# Training Epoch: 38 [11000/17656 (62%)]	Loss: 0.025877
# Training Epoch: 38 [12000/17656 (68%)]	Loss: 0.065449
# Training Epoch: 38 [13000/17656 (74%)]	Loss: 0.016370
# Training Epoch: 38 [14000/17656 (79%)]	Loss: 0.008240
# Training Epoch: 38 [15000/17656 (85%)]	Loss: 0.004497
# Training Epoch: 38 [16000/17656 (91%)]	Loss: 0.001623
# Training Epoch: 38 [17000/17656 (96%)]	Loss: 0.001109
# Validating...
# Validation Epoch: 38 [1000/4414 (23%)]	Loss: 1.424896
# Validation Epoch: 38 [2000/4414 (45%)]	Loss: 1.490944
# Validation Epoch: 38 [3000/4414 (68%)]	Loss: 1.581771
# Validation Epoch: 38 [4000/4414 (90%)]	Loss: 1.331898
# Training Loss: 0.02041884 	Validation Loss 1.44071007 	Training Accuracy 99.411% 	Validation Accuracy 76.801%
#
# EPOCH 39:
# Training...
# Training Epoch: 39 [1000/17656 (6%)]	Loss: 0.000580
# Training Epoch: 39 [2000/17656 (11%)]	Loss: 0.000913
# Training Epoch: 39 [3000/17656 (17%)]	Loss: 0.000581
# Training Epoch: 39 [4000/17656 (23%)]	Loss: 0.000273
# Training Epoch: 39 [5000/17656 (28%)]	Loss: 0.017968
# Training Epoch: 39 [6000/17656 (34%)]	Loss: 0.009784
# Training Epoch: 39 [7000/17656 (40%)]	Loss: 0.016712
# Training Epoch: 39 [8000/17656 (45%)]	Loss: 0.002724
# Training Epoch: 39 [9000/17656 (51%)]	Loss: 0.022168
# Training Epoch: 39 [10000/17656 (57%)]	Loss: 0.004838
# Training Epoch: 39 [11000/17656 (62%)]	Loss: 0.010866
# Training Epoch: 39 [12000/17656 (68%)]	Loss: 0.024901
# Training Epoch: 39 [13000/17656 (74%)]	Loss: 0.059866
# Training Epoch: 39 [14000/17656 (79%)]	Loss: 0.032228
# Training Epoch: 39 [15000/17656 (85%)]	Loss: 0.017914
# Training Epoch: 39 [16000/17656 (91%)]	Loss: 0.014562
# Training Epoch: 39 [17000/17656 (96%)]	Loss: 0.024649
# Validating...
# Validation Epoch: 39 [1000/4414 (23%)]	Loss: 1.324412
# Validation Epoch: 39 [2000/4414 (45%)]	Loss: 1.476256
# Validation Epoch: 39 [3000/4414 (68%)]	Loss: 1.588153
# Validation Epoch: 39 [4000/4414 (90%)]	Loss: 1.346258
# Training Loss: 0.01497758 	Validation Loss 1.42110544 	Training Accuracy 99.524% 	Validation Accuracy 76.235%
#
# EPOCH 40:
# Training...
# Training Epoch: 40 [1000/17656 (6%)]	Loss: 0.002980
# Training Epoch: 40 [2000/17656 (11%)]	Loss: 0.005532
# Training Epoch: 40 [3000/17656 (17%)]	Loss: 0.006043
# Training Epoch: 40 [4000/17656 (23%)]	Loss: 0.006448
# Training Epoch: 40 [5000/17656 (28%)]	Loss: 0.007227
# Training Epoch: 40 [6000/17656 (34%)]	Loss: 0.022860
# Training Epoch: 40 [7000/17656 (40%)]	Loss: 0.003869
# Training Epoch: 40 [8000/17656 (45%)]	Loss: 0.005434
# Training Epoch: 40 [9000/17656 (51%)]	Loss: 0.000654
# Training Epoch: 40 [10000/17656 (57%)]	Loss: 0.000878
# Training Epoch: 40 [11000/17656 (62%)]	Loss: 0.011413
# Training Epoch: 40 [12000/17656 (68%)]	Loss: 0.007884
# Training Epoch: 40 [13000/17656 (74%)]	Loss: 0.022999
# Training Epoch: 40 [14000/17656 (79%)]	Loss: 0.004794
# Training Epoch: 40 [15000/17656 (85%)]	Loss: 0.016301
# Training Epoch: 40 [16000/17656 (91%)]	Loss: 0.011941
# Training Epoch: 40 [17000/17656 (96%)]	Loss: 0.030700
# Validating...
# Validation Epoch: 40 [1000/4414 (23%)]	Loss: 1.713608
# Validation Epoch: 40 [2000/4414 (45%)]	Loss: 1.650831
# Validation Epoch: 40 [3000/4414 (68%)]	Loss: 1.890157
# Validation Epoch: 40 [4000/4414 (90%)]	Loss: 1.672944
# Training Loss: 0.01030287 	Validation Loss 1.70188123 	Training Accuracy 99.666% 	Validation Accuracy 74.468%
